# %% [markdown]
# <a href="https://colab.research.google.com/github/spesivan/collab_notes/blob/main/bitmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# bitmap bitmap

# %%
from PIL import Image
import numpy as np
import pandas as pd

# %%
colourImg = Image.open("./resized_image_0001.jpg")
colourPixels = colourImg.convert("RGB")
colourArray = np.array(colourPixels.getdata()).reshape(colourImg.size + (3,))
indicesArray = np.moveaxis(np.indices(colourImg.size), 0, 2)
allArray = np.dstack((indicesArray, colourArray)).reshape((-1, 5))

# %%
df = pd.DataFrame(allArray, columns=["y", "x", "red","green","blue"])
df
# Out:
#          y    x  red  green  blue
# 0        0    0  250    250   250
# 1        0    1  248    248   248
# 2        0    2  251    251   251
# 3        0    3  250    250   250
# 4        0    4  251    251   251
# ...    ...  ...  ...    ...   ...
# 16379  127  123  249    249   249
# 16380  127  124  253    253   253
# 16381  127  125  252    252   252
# 16382  127  126  252    252   252
# 16383  127  127  250    250   250
#
# [16384 rows x 5 columns]

# %%
df.to_excel(f'renk_koordinatları.xlsx', index=False)
